# %% [markdown]
# <a href="https://colab.research.google.com/github/sidsharma1210/PYTHON/blob/main/Python_operators_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Operators Practice Notebook
#
# Each question is followed by its solution in the next code cell.
# Difficulty level: Easy to Medium.

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# Q1. Add two numbers a = 10 and b = 5.

# %%
a=10
b=5
print(a+b)
# Out:
# 15

# %% [markdown]
# Q2. Find the remainder when 17 is divided by 4.

# %%
a=17
b=4
print(a%b)
# Out:
# 1

# %% [markdown]
# Q3. Calculate 3 raised to the power 4.

# %%
a=3
b=4
print(a**b)
# Out:
# 81

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# Q4. Assign 10 to x and add 5 to it using assignment operator.

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %% [markdown]
# Q5. Assign 20 to y and multiply it by 2 using assignment operator.

# %%
y = 20
y *= 2
print(y)
# Out:
# 40

# %% [markdown]
# Q6. Assign 15 to z and subtract 7 using assignment operator.

# %%
z = 15
z -= 7
print(z)
# Out:
# 8

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Q7. Check if 10 is greater than 5.

# %%
10>5
# Out:
# True

# %% [markdown]
# Q8. Check if 7 is equal to 9.

# %%
7==9
# Out:
# False

# %% [markdown]
# Q9. Check if 8 is not equal to 3.

# %%
8!=3
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# Q10. Check if 5 > 2 and 10 > 3.

# %%
5 > 2 and 10 > 3
# Out:
# True

# %% [markdown]
# Q11. Check if 5 > 10 or 3 < 7.

# %%
5 > 10 or 3 < 7
# Out:
# True

# %% [markdown]
# Q12. Use not operator on condition 10 > 5.

# %%
a =10 > 5
print(not a )
# Out:
# False

# %% [markdown]
# ## Identity Operators

# %% [markdown]
# Q16. Check if a and b refer to the same object.
# Let a = 10, b = 10.

# %%
a =10
b = 10
a ==b
# Out:
# True

# %% [markdown]
# Q18. Compare identity of two variables c and d where c = d = 5.

# %%
c= d = 5
print(c is d)
# Out:
# True

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# Q19. Check if 3 is present in the list [1,2,3,4].

# %%
x,y,z,a = [1,2,3,4]
x==3 or y==3 or z==3 or a==3
# Out:
# True

# %% [markdown]
# Q20. Check if 'a' is not present in the string 'python'.

# %%
s = "python"
print('a' in s)
# Out:
# False

# %% [markdown]
# Q21. Check if 10 is in the tuple (5, 10, 15).

# %%
a = (5,10,15)
print(10 in a)
# Out:
# True
